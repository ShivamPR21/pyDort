# %%
import pandas as pd
import numpy
import plotly.express as px

# %%
data_gt = pd.read_csv("../results/results_cl/train1/tracks_dump_exp4_cv-cv_contrastive_resnet18_tracker/043aeba7-14e5-3cde-8a5c-639389b6d3a6/per_sweep_annotations_amodal/True_tracks.csv")
data_pt = pd.read_csv("../results/results_cl/train1/tracks_dump_exp4_cv-cv_contrastive_resnet18_tracker/043aeba7-14e5-3cde-8a5c-639389b6d3a6/per_sweep_annotations_amodal/Pred_tracks.csv")

# %%
# data_pt.loc[:, ['x', 'y']] += [10, 1]

# %%
fig = px.scatter(data_pt, x="x", y="y", color="R")
fig.show()
# Out:
# <div>                            <div id="eb420622-6a3b-4e56-a6b7-86d453b0f5c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb420622-6a3b-4e56-a6b7-86d453b0f5c4")) {                    Plotly.newPlot(                        "eb420622-6a3b-4e56-a6b7-86d453b0f5c4",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>R=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0,193.0
# ...

# %%
fig = px.scatter(data_gt, x="x", y="y", color="R")
fig.show()
# Out:
# <div>                            <div id="38d0493e-975d-4689-8ae6-e04addf01fdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38d0493e-975d-4689-8ae6-e04addf01fdb")) {                    Plotly.newPlot(                        "38d0493e-975d-4689-8ae6-e04addf01fdb",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>R=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0,169.0
# ...

# %%
import torch

# %%
a = torch.rand(21, 512)
b = torch.rand(5, 512, 79)

# %%
(a @ b).shape
# Out:
# torch.Size([5, 21, 79])

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a.multiply(b)
#
# RuntimeError: The size of tensor a (512) must match the size of tensor b (2) at non-singleton dimension 2
